# %%
import os
image_dir = 'ui_elements'
"""掃描資料夾裡所有的圖片,建立索引"""
elements = {}
if not os.path.exists(image_dir):
    os.makedirs(image_dir)
    print(elements)

for filename in os.listdir(image_dir):
    if filename.endswith(('.png', '.jpg')):
        # 檔名去掉副檔名當作元件名稱
        name = os.path.splitext(filename)[0]
        elements[name] = os.path.join(image_dir, filename)

print(elements)
# Out:
# {'close_button': 'ui_elements\\close_button.png', 'save_dialog': 'ui_elements\\save_dialog.png'}
