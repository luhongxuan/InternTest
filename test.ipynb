# %%
log = {"timestamp": "2026-07-09 11:22:22", "event": "browser_observation", "step": 1, "url": "https://www.thsrc.com.tw/ArticleContent/a3b630bb-1066-4352-a1ef-58c7b4e8ef7c#", "page_title": "時刻表與票價查詢 – 台灣高鐵", "elements_count": 32, "screenshot_path": "screenshots\\browser_20260709_112222.png", "ws_connected": True, "observation": [{"element_id": "el_0", "tag": "a", "role": "link", "text": "", "label": "", "aria_label": "", "placeholder": "", "title": "回到高鐵首頁", "bounds": {"x": 49.0, "y": 57.0, "width": 210.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_1", "tag": "a", "role": "link", "text": "", "label": "搜尋", "aria_label": "搜尋", "placeholder": "", "title": "搜尋", "bounds": {"x": 1004.0, "y": 100.0, "width": 22.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_2", "tag": "a", "role": "link", "text": "網路訂票", "label": "", "aria_label": "", "placeholder": "", "title": "網路訂票[另開新視窗]", "bounds": {"x": 1208.0, "y": 447.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_3", "tag": "a", "role": "link", "text": "會員專區", "label": "", "aria_label": "", "placeholder": "", "title": "會員專區[另開新視窗]", "bounds": {"x": 1208.0, "y": 519.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_4", "tag": "a", "role": "link", "text": "數位客服", "label": "", "aria_label": "", "placeholder": "", "title": "數位客服[另開新視窗]", "bounds": {"x": 1208.0, "y": 591.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_5", "tag": "a", "role": "link", "text": "TOP", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 1208.0, "y": 653.0, "width": 80.0, "height": 44.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_6", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 340.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_7", "tag": "a", "role": "link", "text": "乘車指南", "label": "", "aria_label": "", "placeholder": "", "title": "乘車指南", "bounds": {"x": 486.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_8", "tag": "a", "role": "link", "text": "搭高鐵・遊台灣", "label": "", "aria_label": "", "placeholder": "", "title": "搭高鐵・遊台灣", "bounds": {"x": 633.0, "y": 61.0, "width": 204.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_9", "tag": "a", "role": "link", "text": "關於高鐵", "label": "", "aria_label": "", "placeholder": "", "title": "關於高鐵", "bounds": {"x": 838.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_10", "tag": "a", "role": "link", "text": "網站導覽", "label": "", "aria_label": "", "placeholder": "", "title": "網站導覽[另開新視窗]", "bounds": {"x": 614.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_11", "tag": "a", "role": "link", "text": "企業永續發展", "label": "", "aria_label": "", "placeholder": "", "title": "企業永續發展[另開新視窗]", "bounds": {"x": 702.0, "y": 18.0, "width": 86.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_12", "tag": "a", "role": "link", "text": "投資人關係", "label": "", "aria_label": "", "placeholder": "", "title": "投資人關係[另開新視窗]", "bounds": {"x": 819.0, "y": 18.0, "width": 72.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_13", "tag": "a", "role": "link", "text": "公司治理", "label": "", "aria_label": "", "placeholder": "", "title": "公司治理[另開新視窗]", "bounds": {"x": 922.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_14", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "一般字體", "bounds": {"x": 1009.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_15", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "放大字體", "bounds": {"x": 1048.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_16", "tag": "button", "role": "button", "text": "繁體中文", "label": "", "aria_label": "", "placeholder": "", "title": "Language網站語言選擇", "bounds": {"x": 1113.0, "y": 11.0, "width": 106.0, "height": 34.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_17", "tag": "a", "role": "link", "text": "首頁", "label": "", "aria_label": "", "placeholder": "", "title": "首頁", "bounds": {"x": 114.0, "y": 153.0, "width": 26.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_18", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 160.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_19", "tag": "a", "role": "link", "text": "快速查詢", "label": "", "aria_label": "", "placeholder": "", "title": "快速查詢", "bounds": {"x": 232.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_20", "tag": "button", "role": "button", "text": "列印本頁", "label": "", "aria_label": "", "placeholder": "", "title": "列印本頁", "bounds": {"x": 1077.0, "y": 145.0, "width": 107.0, "height": 36.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_21", "tag": "a", "role": "link", "text": "時刻表下載", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "時刻表下載", "bounds": {"x": 1042.0, "y": 248.0, "width": 142.0, "height": 41.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_22", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "出發站", "bounds": {"x": 154.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "出發站", "occluded": False}, {"element_id": "el_23", "tag": "button", "role": "button", "text": "", "label": "交換", "aria_label": "交換", "placeholder": "", "title": "", "bounds": {"x": 262.0, "y": 394.0, "width": 27.0, "height": 40.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_24", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "到達站", "bounds": {"x": 305.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "到達站", "occluded": False}, {"element_id": "el_25", "tag": "select", "role": "select", "text": "單程\n去回程", "label": "", "aria_label": "", "placeholder": "", "title": "票種", "bounds": {"x": 417.0, "y": 392.0, "width": 101.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_26", "tag": "input", "role": "text", "text": "2026/07/09", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 538.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發日期", "occluded": False}, {"element_id": "el_27", "tag": "input", "role": "text", "text": "11:30", "label": "", "aria_label": "", "placeholder": "出發時間", "title": "", "bounds": {"x": 697.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發時間", "occluded": False}, {"element_id": "el_28", "tag": "button", "role": "button", "text": "適用優惠", "label": "", "aria_label": "", "placeholder": "", "title": "適用優惠", "bounds": {"x": 859.0, "y": 392.0, "width": 136.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_29", "tag": "button", "role": "button", "text": "查詢", "label": "", "aria_label": "", "placeholder": "", "title": "查詢", "bounds": {"x": 1011.0, "y": 384.0, "width": 136.0, "height": 52.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_30", "tag": "a", "role": "link", "text": "票價產品一覽表", "label": "", "aria_label": "", "placeholder": "", "title": "票價產品一覽表", "bounds": {"x": 604.0, "y": 723.0, "width": 106.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "早鳥優惠採記名制並限量銷售。各專案優惠票價之詳細規定，敬請參考 。", "occluded": False}, {"element_id": "el_31", "tag": "a", "role": "link", "text": "2026/2/2起適用時刻表", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "2026/2/2起適用時刻表.pdf[另開新視窗]", "bounds": {"x": 756.0, "y": 692.0, "width": 182.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}]}

print(log["observation"])
for e in log["observation"]:
    print(e)
# Out:
# [{'element_id': 'el_0', 'tag': 'a', 'role': 'link', 'text': '', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '回到高鐵首頁', 'bounds': {'x': 49.0, 'y': 57.0, 'width': 210.0, 'height': 84.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_1', 'tag': 'a', 'role': 'link', 'text': '', 'label': '搜尋', 'aria_label': '搜尋', 'placeholder': '', 'title': '搜尋', 'bounds': {'x': 1004.0, 'y': 100.0, 'width': 22.0, 'height': 22.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_2', 'tag': 'a', 'role': 'link', 'text': '網路訂票', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '網路訂票[另開新視窗]', 'bounds': {'x': 1208.0, 'y': 447.0, 'width': 80.0, 'height': 57.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_3', 'tag': 'a', 'role': 'link', 
# ...

# %%
{"timestamp": "2026-07-09 11:36:06", "event": "browser_observation", "step": 1, "url": "https://www.thsrc.com.tw/ArticleContent/a3b630bb-1066-4352-a1ef-58c7b4e8ef7c#", "page_title": "時刻表與票價查詢 – 台灣高鐵", "elements_count": 32, "screenshot_path": "screenshots\\browser_20260709_113606.png", "ws_connected": True, "observation": [{"element_id": "el_0", "tag": "a", "role": "link", "text": "", "label": "", "aria_label": "", "placeholder": "", "title": "回到高鐵首頁", "bounds": {"x": 49.0, "y": 57.0, "width": 210.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_1", "tag": "a", "role": "link", "text": "", "label": "搜尋", "aria_label": "搜尋", "placeholder": "", "title": "搜尋", "bounds": {"x": 1004.0, "y": 100.0, "width": 22.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_2", "tag": "a", "role": "link", "text": "網路訂票", "label": "", "aria_label": "", "placeholder": "", "title": "網路訂票[另開新視窗]", "bounds": {"x": 1208.0, "y": 447.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_3", "tag": "a", "role": "link", "text": "會員專區", "label": "", "aria_label": "", "placeholder": "", "title": "會員專區[另開新視窗]", "bounds": {"x": 1208.0, "y": 519.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_4", "tag": "a", "role": "link", "text": "數位客服", "label": "", "aria_label": "", "placeholder": "", "title": "數位客服[另開新視窗]", "bounds": {"x": 1208.0, "y": 591.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_5", "tag": "a", "role": "link", "text": "TOP", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 1208.0, "y": 653.0, "width": 80.0, "height": 44.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_6", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 340.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_7", "tag": "a", "role": "link", "text": "乘車指南", "label": "", "aria_label": "", "placeholder": "", "title": "乘車指南", "bounds": {"x": 486.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_8", "tag": "a", "role": "link", "text": "搭高鐵・遊台灣", "label": "", "aria_label": "", "placeholder": "", "title": "搭高鐵・遊台灣", "bounds": {"x": 633.0, "y": 61.0, "width": 204.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_9", "tag": "a", "role": "link", "text": "關於高鐵", "label": "", "aria_label": "", "placeholder": "", "title": "關於高鐵", "bounds": {"x": 838.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_10", "tag": "a", "role": "link", "text": "網站導覽", "label": "", "aria_label": "", "placeholder": "", "title": "網站導覽[另開新視窗]", "bounds": {"x": 614.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_11", "tag": "a", "role": "link", "text": "企業永續發展", "label": "", "aria_label": "", "placeholder": "", "title": "企業永續發展[另開新視窗]", "bounds": {"x": 702.0, "y": 18.0, "width": 86.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_12", "tag": "a", "role": "link", "text": "投資人關係", "label": "", "aria_label": "", "placeholder": "", "title": "投資人關係[另開新視窗]", "bounds": {"x": 819.0, "y": 18.0, "width": 72.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_13", "tag": "a", "role": "link", "text": "公司治理", "label": "", "aria_label": "", "placeholder": "", "title": "公司治理[另開新視窗]", "bounds": {"x": 922.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_14", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "一般字體", "bounds": {"x": 1009.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_15", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "放大字體", "bounds": {"x": 1048.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_16", "tag": "button", "role": "button", "text": "繁體中文", "label": "", "aria_label": "", "placeholder": "", "title": "Language網站語言選擇", "bounds": {"x": 1113.0, "y": 11.0, "width": 106.0, "height": 34.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_17", "tag": "a", "role": "link", "text": "首頁", "label": "", "aria_label": "", "placeholder": "", "title": "首頁", "bounds": {"x": 114.0, "y": 153.0, "width": 26.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_18", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 160.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_19", "tag": "a", "role": "link", "text": "快速查詢", "label": "", "aria_label": "", "placeholder": "", "title": "快速查詢", "bounds": {"x": 232.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_20", "tag": "button", "role": "button", "text": "列印本頁", "label": "", "aria_label": "", "placeholder": "", "title": "列印本頁", "bounds": {"x": 1077.0, "y": 145.0, "width": 107.0, "height": 36.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_21", "tag": "a", "role": "link", "text": "時刻表下載", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "時刻表下載", "bounds": {"x": 1042.0, "y": 248.0, "width": 142.0, "height": 41.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_22", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "出發站", "bounds": {"x": 154.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "出發站", "occluded": False}, {"element_id": "el_23", "tag": "button", "role": "button", "text": "", "label": "交換", "aria_label": "交換", "placeholder": "", "title": "", "bounds": {"x": 262.0, "y": 394.0, "width": 27.0, "height": 40.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_24", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "到達站", "bounds": {"x": 305.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "到達站", "occluded": False}, {"element_id": "el_25", "tag": "select", "role": "select", "text": "單程\n去回程", "label": "", "aria_label": "", "placeholder": "", "title": "票種", "bounds": {"x": 417.0, "y": 392.0, "width": 101.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_26", "tag": "input", "role": "text", "text": "2026/07/09", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 538.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發日期", "occluded": False}, {"element_id": "el_27", "tag": "input", "role": "text", "text": "11:30", "label": "", "aria_label": "", "placeholder": "出發時間", "title": "", "bounds": {"x": 697.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發時間", "occluded": False}, {"element_id": "el_28", "tag": "button", "role": "button", "text": "適用優惠", "label": "", "aria_label": "", "placeholder": "", "title": "適用優惠", "bounds": {"x": 859.0, "y": 392.0, "width": 136.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_29", "tag": "button", "role": "button", "text": "查詢", "label": "", "aria_label": "", "placeholder": "", "title": "查詢", "bounds": {"x": 1011.0, "y": 384.0, "width": 136.0, "height": 52.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_30", "tag": "a", "role": "link", "text": "票價產品一覽表", "label": "", "aria_label": "", "placeholder": "", "title": "票價產品一覽表", "bounds": {"x": 604.0, "y": 723.0, "width": 106.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "早鳥優惠採記名制並限量銷售。各專案優惠票價之詳細規定，敬請參考 。", "occluded": False}, {"element_id": "el_31", "tag": "a", "role": "link", "text": "2026/2/2起適用時刻表", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "2026/2/2起適用時刻表.pdf[另開新視窗]", "bounds": {"x": 756.0, "y": 692.0, "width": 182.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}]}
{"timestamp": "2026-07-09 11:36:22", "event": "model_response", "step": 1, "state": "executing", "raw": "{\n  \"observation\": \"目前頁面顯示了時刻表與票價查詢界面，需要輸入出發站為台北，抵達站為台中，日期為明天09:00。当前元素清單中有出发站和到达站的下拉菜单。\",\n  \"plan\": \"首先选择出发站为台北\",\n  \"action\": \"click_element\",\n  \"reason\": \"需要点击出发站下拉菜单来选择台北作为出发站点\",\n  \"element_id\": \"el_22\"\n}", "parsed_ok": True}
{"timestamp": "2026-07-09 11:36:22", "event": "action_validation", "step": 1, "ok": True, "error": "", "action": {"action": "click_element", "reason": "需要点击出发站下拉菜单来选择台北作为出发站点", "observation": "目前頁面顯示了時刻表與票價查詢界面，需要輸入出發站為台北，抵達站為台中，日期為明天09:00。当前元素清單中有出发站和到达站的下拉菜单。", "plan": "首先选择出发站为台北", "element_id": "el_22"}}
{"timestamp": "2026-07-09 11:36:22", "event": "action_safety", "step": 1, "verdict": "allow", "reason": ""}

print(log["observation"])
for e in log["observation"]:
    print(e)
# Out:
# [{'element_id': 'el_0', 'tag': 'a', 'role': 'link', 'text': '', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '回到高鐵首頁', 'bounds': {'x': 49.0, 'y': 57.0, 'width': 210.0, 'height': 84.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_1', 'tag': 'a', 'role': 'link', 'text': '', 'label': '搜尋', 'aria_label': '搜尋', 'placeholder': '', 'title': '搜尋', 'bounds': {'x': 1004.0, 'y': 100.0, 'width': 22.0, 'height': 22.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_2', 'tag': 'a', 'role': 'link', 'text': '網路訂票', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '網路訂票[另開新視窗]', 'bounds': {'x': 1208.0, 'y': 447.0, 'width': 80.0, 'height': 57.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_3', 'tag': 'a', 'role': 'link', 
# ...

# %%
log = {"timestamp": "2026-07-09 13:52:59", "event": "browser_observation", "step": 1, "url": "https://www.thsrc.com.tw/ArticleContent/a3b630bb-1066-4352-a1ef-58c7b4e8ef7c", "page_title": "時刻表與票價查詢 – 台灣高鐵", "elements_count": 32, "screenshot_path": "screenshots\\browser_20260709_135259.png", "ws_connected": True, "observation": [{"element_id": "el_0", "tag": "a", "role": "link", "text": "", "label": "", "aria_label": "", "placeholder": "", "title": "回到高鐵首頁", "bounds": {"x": 49.0, "y": 57.0, "width": 210.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_1", "tag": "a", "role": "link", "text": "", "label": "搜尋", "aria_label": "搜尋", "placeholder": "", "title": "搜尋", "bounds": {"x": 1004.0, "y": 100.0, "width": 22.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_2", "tag": "a", "role": "link", "text": "網路訂票", "label": "", "aria_label": "", "placeholder": "", "title": "網路訂票[另開新視窗]", "bounds": {"x": 1208.0, "y": 447.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_3", "tag": "a", "role": "link", "text": "會員專區", "label": "", "aria_label": "", "placeholder": "", "title": "會員專區[另開新視窗]", "bounds": {"x": 1208.0, "y": 519.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_4", "tag": "a", "role": "link", "text": "數位客服", "label": "", "aria_label": "", "placeholder": "", "title": "數位客服[另開新視窗]", "bounds": {"x": 1208.0, "y": 591.0, "width": 80.0, "height": 57.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_5", "tag": "a", "role": "link", "text": "TOP", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 1208.0, "y": 653.0, "width": 80.0, "height": 44.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_6", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 340.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_7", "tag": "a", "role": "link", "text": "乘車指南", "label": "", "aria_label": "", "placeholder": "", "title": "乘車指南", "bounds": {"x": 486.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_8", "tag": "a", "role": "link", "text": "搭高鐵・遊台灣", "label": "", "aria_label": "", "placeholder": "", "title": "搭高鐵・遊台灣", "bounds": {"x": 633.0, "y": 61.0, "width": 204.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_9", "tag": "a", "role": "link", "text": "關於高鐵", "label": "", "aria_label": "", "placeholder": "", "title": "關於高鐵", "bounds": {"x": 838.0, "y": 61.0, "width": 147.0, "height": 84.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_10", "tag": "a", "role": "link", "text": "網站導覽", "label": "", "aria_label": "", "placeholder": "", "title": "網站導覽[另開新視窗]", "bounds": {"x": 614.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_11", "tag": "a", "role": "link", "text": "企業永續發展", "label": "", "aria_label": "", "placeholder": "", "title": "企業永續發展[另開新視窗]", "bounds": {"x": 702.0, "y": 18.0, "width": 86.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_12", "tag": "a", "role": "link", "text": "投資人關係", "label": "", "aria_label": "", "placeholder": "", "title": "投資人關係[另開新視窗]", "bounds": {"x": 819.0, "y": 18.0, "width": 72.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_13", "tag": "a", "role": "link", "text": "公司治理", "label": "", "aria_label": "", "placeholder": "", "title": "公司治理[另開新視窗]", "bounds": {"x": 922.0, "y": 18.0, "width": 58.0, "height": 16.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_14", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "一般字體", "bounds": {"x": 1009.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_15", "tag": "button", "role": "button", "text": "A", "label": "", "aria_label": "", "placeholder": "", "title": "放大字體", "bounds": {"x": 1048.0, "y": 13.0, "width": 30.0, "height": 30.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_16", "tag": "button", "role": "button", "text": "繁體中文", "label": "", "aria_label": "", "placeholder": "", "title": "Language網站語言選擇", "bounds": {"x": 1113.0, "y": 11.0, "width": 106.0, "height": 34.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_17", "tag": "a", "role": "link", "text": "首頁", "label": "", "aria_label": "", "placeholder": "", "title": "首頁", "bounds": {"x": 114.0, "y": 153.0, "width": 26.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_18", "tag": "a", "role": "link", "text": "購票資訊", "label": "", "aria_label": "", "placeholder": "", "title": "購票資訊", "bounds": {"x": 160.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_19", "tag": "a", "role": "link", "text": "快速查詢", "label": "", "aria_label": "", "placeholder": "", "title": "快速查詢", "bounds": {"x": 232.0, "y": 153.0, "width": 51.0, "height": 19.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_20", "tag": "button", "role": "button", "text": "列印本頁", "label": "", "aria_label": "", "placeholder": "", "title": "列印本頁", "bounds": {"x": 1077.0, "y": 145.0, "width": 107.0, "height": 36.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_21", "tag": "a", "role": "link", "text": "時刻表下載", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "時刻表下載", "bounds": {"x": 1042.0, "y": 248.0, "width": 142.0, "height": 41.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_22", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "出發站", "bounds": {"x": 154.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "出發站", "occluded": False}, {"element_id": "el_23", "tag": "button", "role": "button", "text": "", "label": "交換", "aria_label": "交換", "placeholder": "", "title": "", "bounds": {"x": 262.0, "y": 394.0, "width": 27.0, "height": 40.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_24", "tag": "select", "role": "select", "text": "南港\n台北\n板橋\n桃園\n新竹\n苗栗\n台中\n彰化\n雲林\n嘉義\n台南\n左營", "label": "", "aria_label": "", "placeholder": "", "title": "到達站", "bounds": {"x": 305.0, "y": 392.0, "width": 92.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "到達站", "occluded": False}, {"element_id": "el_25", "tag": "select", "role": "select", "text": "單程\n去回程", "label": "", "aria_label": "", "placeholder": "", "title": "票種", "bounds": {"x": 417.0, "y": 392.0, "width": 101.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_26", "tag": "input", "role": "text", "text": "2026/07/09", "label": "", "aria_label": "", "placeholder": "", "title": "", "bounds": {"x": 538.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發日期", "occluded": False}, {"element_id": "el_27", "tag": "input", "role": "text", "text": "14:00", "label": "", "aria_label": "", "placeholder": "出發時間", "title": "", "bounds": {"x": 697.0, "y": 392.0, "width": 144.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": False, "inputtable": True, "nearby_text": "出發時間", "occluded": False}, {"element_id": "el_28", "tag": "button", "role": "button", "text": "適用優惠", "label": "", "aria_label": "", "placeholder": "", "title": "適用優惠", "bounds": {"x": 859.0, "y": 392.0, "width": 136.0, "height": 42.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_29", "tag": "button", "role": "button", "text": "查詢", "label": "", "aria_label": "", "placeholder": "", "title": "查詢", "bounds": {"x": 1011.0, "y": 384.0, "width": 136.0, "height": 52.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}, {"element_id": "el_30", "tag": "a", "role": "link", "text": "票價產品一覽表", "label": "", "aria_label": "", "placeholder": "", "title": "票價產品一覽表", "bounds": {"x": 604.0, "y": 723.0, "width": 106.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "早鳥優惠採記名制並限量銷售。各專案優惠票價之詳細規定，敬請參考 。", "occluded": False}, {"element_id": "el_31", "tag": "a", "role": "link", "text": "2026/2/2起適用時刻表", "label": "時刻表下載", "aria_label": "時刻表下載", "placeholder": "", "title": "2026/2/2起適用時刻表.pdf[另開新視窗]", "bounds": {"x": 756.0, "y": 692.0, "width": 182.0, "height": 22.0}, "visible": True, "enabled": True, "clickable": True, "inputtable": False, "nearby_text": "", "occluded": False}]}

print(log["observation"])
for e in log["observation"]:
    print(e)
# Out:
# [{'element_id': 'el_0', 'tag': 'a', 'role': 'link', 'text': '', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '回到高鐵首頁', 'bounds': {'x': 49.0, 'y': 57.0, 'width': 210.0, 'height': 84.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_1', 'tag': 'a', 'role': 'link', 'text': '', 'label': '搜尋', 'aria_label': '搜尋', 'placeholder': '', 'title': '搜尋', 'bounds': {'x': 1004.0, 'y': 100.0, 'width': 22.0, 'height': 22.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_2', 'tag': 'a', 'role': 'link', 'text': '網路訂票', 'label': '', 'aria_label': '', 'placeholder': '', 'title': '網路訂票[另開新視窗]', 'bounds': {'x': 1208.0, 'y': 447.0, 'width': 80.0, 'height': 57.0}, 'visible': True, 'enabled': True, 'clickable': True, 'inputtable': False, 'nearby_text': '', 'occluded': False}, {'element_id': 'el_3', 'tag': 'a', 'role': 'link', 
# ...
